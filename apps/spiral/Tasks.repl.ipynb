// %% [markdown]
// ## Tasks (Polyglot)

// %%
// // rust

inl types () =
    global "[<Fable.Core.Erase; Fable.Core.Emit(\"std::string::String\")>] type std_string_String = class end"
    global "[<Fable.Core.Erase; Fable.Core.Emit(\"&$0\")>] type Ref<'T> = class end"
    global "[<Fable.Core.Erase; Fable.Core.Emit(\"str\")>] type Str = class end"

inl emit_expr forall a t. (args : a) (code : string) : t =
    real
        $"Fable.Core.Rust.emitExpr !args !code" : t


nominal std_string = $"std_string_String"
nominal ref' t = $"Ref<`t>"
nominal str = $"Str"

inl format_debug forall t. (x : t) : std_string =
    real
        emit_expr `t `std_string x "format!(\"{:?}\", $0)"

inl format_pretty forall t. (x : t) : std_string =
    real
        emit_expr `t `std_string x "format!(\"{:#?}\", $0)"

inl to_std_string (str : ref' str) : std_string =
    // inl str = join str
    // // emit_expr () $"\"!str.to_string()\""
    // // emit_expr () $"\"alloc::string::to_string(!str)\""
    // emit_expr str "($0).to_string()"
    emit_expr str $"\"String::from(core::ops::Deref::deref($0))\""
    // emit_expr str $"\"String::from(*$0)\""
    // emit_expr () $"\"String::from(!str)\""

inl format forall t. (x : t) : std_string =
    real
        inl result : std_string =
            typecase t with
            | string => to_std_string x
            | std_string => x
            | _ => format_pretty `t x
        result

inl raw_string_literal (s : string) : ref' str =
    emit_expr () $"\"r#\\\"\" + !s + \"\\\"#\""

inl (~#) (s : string) : ref' str =
    raw_string_literal s
// Out:
// .fsx:
// ()

// %%
// // rust

nominal task_name = string

union manual_scheduling =
    | WithSuggestion
    | WithoutSuggestion

union recurrency_offset =
    | Days : i32
    | Weeks : i32
    | Months : i32

union day_of_week =
    | Sunday
    | Monday
    | Tuesday
    | Wednesday
    | Thursday
    | Friday
    | Saturday

union month =
    | January
    | February
    | March
    | April
    | May
    | June
    | July
    | August
    | September
    | October
    | November
    | December

nominal day = i32
nominal year = i32

union fixed_recurrency =
    | Weekly : day_of_week
    | Monthly : day
    | Yearly : day * month

union recurrency =
    | Offset : recurrency_offset
    | Fixed : list fixed_recurrency

union scheduling =
    | Manual : manual_scheduling
    | Recurrent : recurrency

type task =
    {
        name : task_name
        scheduling : scheduling
    }

type date =
    {
        year : year
        month : month
        day : day
    }

union status =
    | Postponed : option ()

type event =
    {
        date : date
        status : status
    }

type task_template =
    {
        task : task
        events : list event
    }

inl tasks : list task_template =
    [
        {
            task =
                {
                    name = task_name "01"
                    scheduling = Manual WithSuggestion
                }
            events = []
        }
        {
            task =
                {
                    name = task_name "02"
                    scheduling = Manual WithSuggestion
                }
            events = []
        }
        {
            task =
                {
                    name = task_name "03"
                    scheduling = Manual WithSuggestion
                }
            events = []
        }
    ]

types ()

tasks |> format_pretty |> fsharp.console.write_line
// Out:
// .rs output:
// UH2_0(
//     UH0_1,
//     "01",
//     US4_0(
//         US3_0,
//     ),
//     UH2_0(
//         UH0_1,
//         "02",
//         US4_0(
//             US3_0,
//         ),
//         UH2_0(
//             UH0_1,
//             "03",
//             US4_0(
//                 US3_0,
//             ),
//             UH2_1,
//         ),
//     ),
// )
// .fsx:
// [<Fable.Core.Erase; Fable.Core.Emit("std::string::String")>] type std_string_String = class end
// [<Fable.Core.Erase; Fable.Core.Emit("&$0")>] type Ref<'T> = class end
// [<Fable.Core.Erase; Fable.Core.Emit("str")>] type Str = class end
// type [<Struct>] US0 =
//     | US0_0
//     | US0_1
//     | US0_2
//     | US0_3
//     | US0_4
//     | US0_5
//     | US0_6
//     | US0_7
//     | US0_8
//     | US0_9
//     | US0_10
//     | US0_11
// and [<Struct>] US2 =
//     | US2_0
//     | US2_1
// and [<Struct>] US1 =
//     | US1_0 of f0_0 : US2
// and UH0 =
//     | UH0_0 of int32 * US0 * int32 * US1 * UH0
//     | UH0_1
// and [<Struct>] US3 =
//     | US3_0
//     | US3_1
// and [<Struct>] US7 =
//     | US7_0
//     | US7_1
//     | US7_2
//     | US7_3
//     | US7_4
//     | US7_5
//     | US7_6
// and [<Struct>] US6 =
//     | US6_0 of f0_0 : int32
//     | US6_1 of f1_0 : US7
//     | US6_2 of f2_0 : int32 * f2_1 : US0
// and UH1 =
//     | UH1_0 of US6 * UH1
//     | UH1_1
// and [<Struct>] US8 =
//     | US8_0 of f0_0 : int32
//     | US8_1 of f1_0 : int32
//     | US8_2 of f2_0 : int32
// and [<Struct>] US5 =
//     | US5_0 of f0_0 : UH1
//     | US5_1 of f1_0 : US8
// and [<Struct>] US4 =
//     | US4_0 of f0_0 : US3
//     | US4_1 of f1_0 : US5
// and UH2 =
//     | UH2_0 of UH0 * string * US4 * UH2
//     | UH2_1
// let rec method0 () : unit =
//     let v0 : UH0 = UH0_1
//     let v1 : string = "01"
//     let v2 : US3 = US3_0
//     let v3 : US4 = US4_0(v2)
//     let v4 : UH0 = UH0_1
//     let v5 : string = "02"
//     let v6 : US3 = US3_0
//     let v7 : US4 = US4_0(v6)
//     let v8 : UH0 = UH0_1
//     let v9 : string = "03"
//     let v10 : US3 = US3_0
//     let v11 : US4 = US4_0(v10)
//     let v12 : UH2 = UH2_1
//     let v13 : UH2 = UH2_0(v8, v9, v11, v12)
//     let v14 : UH2 = UH2_0(v4, v5, v7, v13)
//     let v15 : UH2 = UH2_0(v0, v1, v3, v14)
//     let v16 : string = "format!(\"{:#?}\", $0)"
//     let v17 : std_string_String = Fable.Core.Rust.emitExpr v15 v16
//     System.Console.WriteLine v17
//     ()
// method0()
//
//
// .rs:
// #![allow(dead_code,)]
// #![allow(non_camel_case_types,)]
// #![allow(non_snake_case,)]
// #![allow(non_upper_case_globals,)]
// #![allow(unreachable_code,)]
// #![allow(unused_attributes,)]
// #![allow(unused_imports,)]
// #![allow(unused_macros,)]
// #![allow(unused_parens,)]
// #![allow(unused_variables,)]
// pub mod Repl_1c2c3f341bc3d90b319bf2e6fee0fa600127d4f51b7dd244904a01039ee73de6 {
//     use super::*;
//     use fable_library_rust::Native_::Any;
//     use fable_library_rust::Native_::LrcPtr;
//     use fable_library_rust::Native_::on_startup;
//     use fable_library_rust::String_::string;
//     #[derive(Clone, Copy, Debug, PartialEq, PartialOrd, Hash, Eq, Ord,)]
//     pub enum US0 {
//         US0_0,
//         US0_1,
//         US0_2,
//         US0_3,
//         US0_4,
//         US0_5,
//         US0_6,
//         US0_7,
//         US0_8,
//         US0_9,
//         US0_10,
//         US0_11,
//     }
//     impl core::fmt::Display for
//      Repl_1c2c3f341bc3d90b319bf2e6fee0fa600127d4f51b7dd244904a01039ee73de6::US0
//      {
//         fn fmt(&self, f: &mut core::fmt::Formatter) -> core::fmt::Result {
//             write!(f, "{}", core::any::type_name::<Self>())
//         }
//     }
//     #[derive(Clone, Copy, Debug, PartialEq, PartialOrd, Hash, Eq, Ord,)]
//     pub enum US2 { US2_0, US2_1, }
//     impl core::fmt::Display for
//      Repl_1c2c3f341bc3d90b319bf2e6fee0fa600127d4f51b7dd244904a01039ee73de6::US2
//      {
//         fn fmt(&self, f: &mut core::fmt::Formatter) -> core::fmt::Result {
//             write!(f, "{}", core::any::type_name::<Self>())
//         }
//     }
//     #[derive(Clone, Copy, Debug, PartialEq, PartialOrd, Hash, Eq, Ord,)]
//     pub enum US1 {
//         US1_0(Repl_1c2c3f341bc3d90b319bf2e6fee0fa600127d4f51b7dd244904a01039ee73de6::US2),
//     }
//     impl core::fmt::Display for
//      Repl_1c2c3f341bc3d90b319bf2e6fee0fa600127d4f51b7dd244904a01039ee73de6::US1
//      {
//         fn fmt(&self, f: &mut core::fmt::Formatter) -> core::fmt::Result {
//             write!(f, "{}", core::any::type_name::<Self>())
//         }
//     }
//     #[derive(Clone, Debug, PartialEq, PartialOrd, Hash, Eq, Ord,)]
//     pub enum UH0 {
//         UH0_0(i32,
//               Repl_1c2c3f341bc3d90b319bf2e6fee0fa600127d4f51b7dd244904a01039ee73de6::US0,
//               i32,
//               Repl_1c2c3f341bc3d90b319bf2e6fee0fa600127d4f51b7dd244904a01039ee73de6::US1,
//               LrcPtr<Repl_1c2c3f341bc3d90b319bf2e6fee0fa600127d4f51b7dd244904a01039ee73de6::UH0>),
//         UH0_1,
//     }
//     impl core::fmt::Display for
//      Repl_1c2c3f341bc3d90b319bf2e6fee0fa600127d4f51b7dd244904a01039ee73de6::UH0
//      {
//         fn fmt(&self, f: &mut core::fmt::Formatter) -> core::fmt::Result {
//             write!(f, "{}", core::any::type_name::<Self>())
//         }
//     }
//     #[derive(Clone, Copy, Debug, PartialEq, PartialOrd, Hash, Eq, Ord,)]
//     pub enum US3 { US3_0, US3_1, }
//     impl core::fmt::Display for
//      Repl_1c2c3f341bc3d90b319bf2e6fee0fa600127d4f51b7dd244904a01039ee73de6::US3
//      {
//         fn fmt(&self, f: &mut core::fmt::Formatter) -> core::fmt::Result {
//             write!(f, "{}", core::any::type_name::<Self>())
//         }
//     }
//     #[derive(Clone, Copy, Debug, PartialEq, PartialOrd, Hash, Eq, Ord,)]
//     pub enum US7 { US7_0, US7_1, US7_2, US7_3, US7_4, US7_5, US7_6, }
//     impl core::fmt::Display for
//      Repl_1c2c3f341bc3d90b319bf2e6fee0fa600127d4f51b7dd244904a01039ee73de6::US7
//      {
//         fn fmt(&self, f: &mut core::fmt::Formatter) -> core::fmt::Result {
//             write!(f, "{}", core::any::type_name::<Self>())
//         }
//     }
//     #[derive(Clone, Copy, Debug, PartialEq, PartialOrd, Hash, Eq, Ord,)]
//     pub enum US6 {
//         US6_0(i32),
//         US6_1(Repl_1c2c3f341bc3d90b319bf2e6fee0fa600127d4f51b7dd244904a01039ee73de6::US7),
//         US6_2(i32,
//               Repl_1c2c3f341bc3d90b319bf2e6fee0fa600127d4f51b7dd244904a01039ee73de6::US0),
//     }
//     impl core::fmt::Display for
//      Repl_1c2c3f341bc3d90b319bf2e6fee0fa600127d4f51b7dd244904a01039ee73de6::US6
//      {
//         fn fmt(&self, f: &mut core::fmt::Formatter) -> core::fmt::Result {
//             write!(f, "{}", core::any::type_name::<Self>())
//         }
//     }
//     #[derive(Clone, Debug, PartialEq, PartialOrd, Hash, Eq, Ord,)]
//     pub enum UH1 {
//         UH1_0(Repl_1c2c3f341bc3d90b319bf2e6fee0fa600127d4f51b7dd244904a01039ee73de6::US6,
//               LrcPtr<Repl_1c2c3f341bc3d90b319bf2e6fee0fa600127d4f51b7dd244904a01039ee73de6::UH1>),
//         UH1_1,
//     }
//     impl core::fmt::Display for
//      Repl_1c2c3f341bc3d90b319bf2e6fee0fa600127d4f51b7dd244904a01039ee73de6::UH1
//      {
//         fn fmt(&self, f: &mut core::fmt::Formatter) -> core::fmt::Result {
//             write!(f, "{}", core::any::type_name::<Self>())
//         }
//     }
//     #[derive(Clone, Copy, Debug, PartialEq, PartialOrd, Hash, Eq, Ord,)]
//     pub enum US8 { US8_0(i32), US8_1(i32), US8_2(i32), }
//     impl core::fmt::Display for
//      Repl_1c2c3f341bc3d90b319bf2e6fee0fa600127d4f51b7dd244904a01039ee73de6::US8
//      {
//         fn fmt(&self, f: &mut core::fmt::Formatter) -> core::fmt::Result {
//             write!(f, "{}", core::any::type_name::<Self>())
//         }
//     }
//     #[derive(Clone, Debug, PartialEq, PartialOrd, Hash, Eq, Ord,)]
//     pub enum US5 {
//         US5_0(LrcPtr<Repl_1c2c3f341bc3d90b319bf2e6fee0fa600127d4f51b7dd244904a01039ee73de6::UH1>),
//         US5_1(Repl_1c2c3f341bc3d90b319bf2e6fee0fa600127d4f51b7dd244904a01039ee73de6::US8),
//     }
//     impl core::fmt::Display for
//      Repl_1c2c3f341bc3d90b319bf2e6fee0fa600127d4f51b7dd244904a01039ee73de6::US5
//      {
//         fn fmt(&self, f: &mut core::fmt::Formatter) -> core::fmt::Result {
//             write!(f, "{}", core::any::type_name::<Self>())
//         }
//     }
//     #[derive(Clone, Debug, PartialEq, PartialOrd, Hash, Eq, Ord,)]
//     pub enum US4 {
//         US4_0(Repl_1c2c3f341bc3d90b319bf2e6fee0fa600127d4f51b7dd244904a01039ee73de6::US3),
//         US4_1(Repl_1c2c3f341bc3d90b319bf2e6fee0fa600127d4f51b7dd244904a01039ee73de6::US5),
//     }
//     impl core::fmt::Display for
//      Repl_1c2c3f341bc3d90b319bf2e6fee0fa600127d4f51b7dd244904a01039ee73de6::US4
//      {
//         fn fmt(&self, f: &mut core::fmt::Formatter) -> core::fmt::Result {
//             write!(f, "{}", core::any::type_name::<Self>())
//         }
//     }
//     #[derive(Clone, Debug, PartialEq, PartialOrd, Hash, Eq, Ord,)]
//     pub enum UH2 {
//         UH2_0(LrcPtr<Repl_1c2c3f341bc3d90b319bf2e6fee0fa600127d4f51b7dd244904a01039ee73de6::UH0>,
//               string,
//               Repl_1c2c3f341bc3d90b319bf2e6fee0fa600127d4f51b7dd244904a01039ee73de6::US4,
//               LrcPtr<Repl_1c2c3f341bc3d90b319bf2e6fee0fa600127d4f51b7dd244904a01039ee73de6::UH2>),
//         UH2_1,
//     }
//     impl core::fmt::Display for
//      Repl_1c2c3f341bc3d90b319bf2e6fee0fa600127d4f51b7dd244904a01039ee73de6::UH2
//      {
//         fn fmt(&self, f: &mut core::fmt::Formatter) -> core::fmt::Result {
//             write!(f, "{}", core::any::type_name::<Self>())
//         }
//     }
//     pub fn method0() {
//         let v17: std::string::String =
//             format!("{:#?}", &LrcPtr::new(Repl_1c2c3f341bc3d90b319bf2e6fee0fa600127d4f51b7dd244904a01039ee73de6::UH2::UH2_0(LrcPtr::new(Repl_1c2c3f341bc3d90b319bf2e6fee0fa600127d4f51b7dd244904a01039ee73de6::UH0::UH0_1),
//                                                                                                                             string("01"),
//                                                                                                                             Repl_1c2c3f341bc3d90b319bf2e6fee0fa600127d4f51b7dd244904a01039ee73de6::US4::US4_0(Repl_1c2c3f341bc3d90b319bf2e6fee0fa600127d4f51b7dd244904a01039ee73de6::US3::US3_0),
//                                                                                                                             LrcPtr::new(Repl_1c2c3f341bc3d90b319bf2e6fee0fa600127d4f51b7dd244904a01039ee73de6::UH2::UH2_0(LrcPtr::new(Repl_1c2c3f341bc3d90b319bf2e6fee0fa600127d4f51b7dd244904a01039ee73de6::UH0::UH0_1),
//                                                                                                                                                                                                                           string("02"),
//                                                                                                                                                                                                                           Repl_1c2c3f341bc3d90b319bf2e6fee0fa600127d4f51b7dd244904a01039ee73de6::US4::US4_0(Repl_1c2c3f341bc3d90b319bf2e6fee0fa600127d4f51b7dd244904a01039ee73de6::US3::US3_0),
//                                                                                                                                                                                                                           LrcPtr::new(Repl_1c2c3f341bc3d90b319bf2e6fee0fa600127d4f51b7dd244904a01039ee73de6::UH2::UH2_0(LrcPtr::new(Repl_1c2c3f341bc3d90b319bf2e6fee0fa600127d4f51b7dd244904a01039ee73de6::UH0::UH0_1),
//                                                                                                                                                                                                                                                                                                                         string("03"),
//                                                                                                                                                                                                                                                                                                                         Repl_1c2c3f341bc3d90b319bf2e6fee0fa600127d4f51b7dd244904a01039ee73de6::US4::US4_0(Repl_1c2c3f341bc3d90b319bf2e6fee0fa600127d4f51b7dd244904a01039ee73de6::US3::US3_0),
//                                                                                                                                                                                                                                                                                                                         LrcPtr::new(Repl_1c2c3f341bc3d90b319bf2e6fee0fa600127d4f51b7dd244904a01039ee73de6::UH2::UH2_1))))))));
//         println!("{0}", &v17,);
//         ()
//     }
//     on_startup!(Repl_1c2c3f341bc3d90b319bf2e6fee0fa600127d4f51b7dd244904a01039ee73de6::method0(),);
// }

// %%
// // test

()
// Out:
// let rec method0 () : unit =
//     ()
// method0()

// %%
// // test

()
// Out:
// let rec method0 () : unit =
//     ()
// method0()

// %%
// // test

()
// Out:
// let rec method0 () : unit =
//     ()
// method0()

// %%
// // test

()
// Out:
// let rec method0 () : unit =
//     ()
// method0()

// %%
// // test

()
// Out:
// let rec method0 () : unit =
//     ()
// method0()

// %%
// // test

()
// Out:
// let rec method0 () : unit =
//     ()
// method0()
